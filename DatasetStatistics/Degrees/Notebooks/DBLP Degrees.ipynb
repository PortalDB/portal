# %% [markdown]
# # DBLP Degrees

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style('whitegrid')
sns.set_context('notebook', font_scale=1.5)

# %%
df = pd.read_csv("../DataFiles/dblp.txt", delim_whitespace=True,  header=None, names=['Degree', 'Count'], index_col=['Degree'])
df.sort_index(inplace=True)

# %%
df.plot()
